# %%
##Definiendo Newton Rhapson ecuacion (e)
##VILLAGRANA APARICIO BRANDON JAIR
import matplotlib.pyplot as plt
import math

# %%
def f(x):
  return (math.exp(-x)-x)

# %%
def f_prima(x):
  return (-math.exp(-x)-1)

# %%
def x_i_next(xi):
  return (xi-(f(xi)/f_prima(xi)))

# %%
x_vec=[]
x_vec.append(0)
contador=int(input("inserte el contador: "))
error_vec=[]
error_vec.append(float(input("inserte el error ")))
criterio_paro=float(input("inserte el criterio de paro: "))
limite=int(input("inserte el limite "))
# Out:
# inserte el contador: 0
# inserte el error 1
# inserte el criterio de paro: 0.0001
# inserte el limite 2

# %%
while((contador <= limite) and error_vec[contador] > criterio_paro):
  x_temp=x_i_next(x_vec[contador])
  x_vec.append(x_temp)
  e_temp=abs(x_vec[contador+1]-x_vec[contador])
  error_vec.append(e_temp)
  contador+=1

  
  if (x_vec[contador]>9999):
    Converge=False
    print("no converge")
  else:
    if (x_vec[contador]<9999):
      Converge=True
      print("Converge")
# Out:
# Converge
# Converge
# Converge

# %%
print(x_vec)
# Out:
# [0, 0.5, 0.5663110031972182, 0.5671431650348622]

# %%
print(error_vec)
# Out:
# [1.0, 0.5, 0.06631100319721817, 0.0008321618376440076]

# %%
plt.plot(x_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(error_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>
