# %%
####DEFINIENDO (5/(2x-1)) semi automatico llamado por el usuario
import matplotlib.pyplot as plt

# %%
def g2(x):
  return (5/(2*x-1))

# %%
x_vec=[]
x_vec.append(0)
contador=int(input("inserte el contador: "))
error_vec=[]
error_vec.append(float(input("inserte el error ")))
criterio_paro=float(input("inserte el criterio de paro: "))
limite=int(input("inserte el limite "))
# Out:
# inserte el contador: 0
# inserte el error 1
# inserte el criterio de paro: 0.0001
# inserte el limite 20

# %%
while((contador <= limite) and error_vec[contador] > criterio_paro):
  x_temp=g2(x_vec[contador])
  x_vec.append(x_temp)
  e_temp=abs(x_vec[contador+1]-x_vec[contador])
  error_vec.append(e_temp)
  contador+=1
  if (x_vec[contador]>9999):
    Converge=False
    print("no converge")
  else:
    if (x_vec[contador]<9999):
      Converge=True
      print("Converge")
# Out:
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge

# %%
print(x_vec)
# Out:
# [0, -5.0, -0.45454545454545453, -2.619047619047619, -0.8015267175572519, -1.9208211143695015, -1.0327074500302846, -1.6311005730092867, -1.1731027768763618, -1.4942297834610216, -1.253616820254888, -1.4256250117609075, -1.2982797713630907, -1.3902174955262983, -1.322599122014749, -1.3716675103170435, -1.3357073231326875, -1.361872869654231, -1.3427339969051033, -1.356679805223534, -1.3464895740054725, -1.3539204527306963]

# %%
print(error_vec)
# Out:
# [1.0, 5.0, 4.545454545454546, 2.1645021645021645, 1.8175209014903673, 1.1192943968122497, 0.8881136643392169, 0.598393122979002, 0.4579977961329249, 0.32112700658465987, 0.24061296320613357, 0.17200819150601943, 0.1273452403978168, 0.09193772416320756, 0.0676183735115492, 0.04906838830229443, 0.03596018718435601, 0.02616554652154357, 0.019138872749127733, 0.01394580831843073, 0.010190231218061507, 0.007430878725223744]

# %%
plt.plot(x_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(error_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
####DEFINIENDO (2**2-5 semi automatico llamado por el usuario)
import matplotlib.pyplot as plt

# %%
def g2(x):
  return ((2*x**2)-5)

# %%
x_vec=[]
x_vec.append(0)
contador=int(input("inserte el contador: "))
error_vec=[]
error_vec.append(float(input("inserte el error ")))
criterio_paro=float(input("inserte el criterio de paro: "))
limite=int(input("inserte el limite "))
# Out:
# inserte el contador: 0
# inserte el error 1
# inserte el criterio de paro: 0.0001
# inserte el limite 5

# %%
while((contador <= limite) and error_vec[contador] > criterio_paro):
  x_temp=g2(x_vec[contador])
  x_vec.append(x_temp)
  e_temp=abs(x_vec[contador+1]-x_vec[contador])
  error_vec.append(e_temp)
  contador+=1

  
  if (x_vec[contador]>9999):
    Converge=False
    print("no converge")
  else:
    if (x_vec[contador]<9999):
      Converge=True
      print("Converge")
# Out:
# Converge
# Converge
# Converge
# no converge
# no converge
# no converge

# %%
print(x_vec)
# Out:
# [0, -5, 45, 4045, 32724045, 2141726242324045, 9173982594118947848565570324045]

# %%
print(error_vec)
# Out:
# [1.0, 5, 50, 4000, 32720000, 2141726209600000, 9173982594118945706839328000000]

# %%
plt.plot(x_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(error_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
####DEFINIENDO (√ ((x+5)/2) semi automatico llamado por el usuario)
import matplotlib.pyplot as plt
import math

# %%
def g2(x):
  return (math.sqrt((x+5)/2))

# %%
x_vec=[]
x_vec.append(0)
contador=int(input("inserte el contador: "))
error_vec=[]
error_vec.append(float(input("inserte el error ")))
criterio_paro=float(input("inserte el criterio de paro: "))
limite=int(input("inserte el limite "))
# Out:
# inserte el contador: 0
# inserte el error 1
# inserte el criterio de paro: 0.0001
# inserte el limite 5

# %%
while((contador <= limite) and error_vec[contador] > criterio_paro):
  x_temp=g2(x_vec[contador])
  x_vec.append(x_temp)
  e_temp=abs(x_vec[contador+1]-x_vec[contador])
  error_vec.append(e_temp)
  contador+=1

  
  if (x_vec[contador]>9999):
    Converge=False
    print("no converge")
  else:
    if (x_vec[contador]<9999):
      Converge=True
      print("Converge")
# Out:
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge

# %%
print(x_vec)
# Out:
# [0, 1.5811388300841898, 1.8139926722680262, 1.8458050645000443, 1.850108789301327, 1.8506902481643608, 1.8507687927134984]

# %%
print(error_vec)

# %%
plt.plot(x_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(error_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
####DEFINIENDO (-√ ((x+5)/2) semi automatico llamado por el usuario)
import matplotlib.pyplot as plt
import math

# %%
def g2(x):
  return (-(math.sqrt((x+5)/2)))

# %%
x_vec=[]
x_vec.append(0)
contador=int(input("inserte el contador: "))
error_vec=[]
error_vec.append(float(input("inserte el error ")))
criterio_paro=float(input("inserte el criterio de paro: "))
limite=int(input("inserte el limite "))
# Out:
# inserte el contador: 0
# inserte el error 1
# inserte el criterio de paro: 0.0001
# inserte el limite 10

# %%
while((contador <= limite) and error_vec[contador] > criterio_paro):
  x_temp=g2(x_vec[contador])
  x_vec.append(x_temp)
  e_temp=abs(x_vec[contador+1]-x_vec[contador])
  error_vec.append(e_temp)
  contador+=1

  
  if (x_vec[contador]>9999):
    Converge=False
    print("no converge")
  else:
    if (x_vec[contador]<9999):
      Converge=True
      print("Converge")
# Out:
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge
# Converge

# %%
print(x_vec)
# Out:
# [0, -1.5811388300841898, -1.3074519436514311, -1.3587766660398184, -1.3493004361446308, -1.3510550625076998, -1.3507303464223162, -1.350790445179726]

# %%
print(error_vec)
# Out:
# [1.0, 1.5811388300841898, 0.2736868864327586, 0.051324722388387256, 0.009476229895187593, 0.0017546263630690007, 0.00032471608538364727, 6.0098757409754455e-05]

# %%
plt.plot(x_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(error_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>
